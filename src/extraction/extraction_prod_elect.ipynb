# %% [markdown]
# # Notebook pour l'ingestion des données de la production d'élèctricité des different Pays

# %% [markdown]
# Import des bibliothèque necessaires:

# %%
import requests
import pandas as pd
from fonction import *

# %% [markdown]
# # 1) Importation des données de production d'electricité de Benin

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    # API nuclear:
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    # API coal:
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    # API natural gas:
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    # API oil: 
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
     # API hydroelec: 
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    # API solar: 
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    # API wind: 
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    # API biomasse: 
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_benin = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_benin['value'] = pd.to_numeric(data_benin['value'], errors='coerce')
data_benin['period'] = pd.to_numeric(data_benin['period'], errors='coerce')


#Affichage
data_benin.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=BEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_benin.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %%
data_2020 = data_benin[data_benin['period']== 2020]

print(data_2020)
# Out:
#     countryRegionName  period        productName   value
# 3               Benin    2020            Nuclear  0.0000
# 47              Benin    2020               Coal  0.0000
# 91              Benin    2020        Natural gas  0.7490
# 135             Benin    2020                Oil  0.2326
# 179             Benin    2020   Hydroelectricity  0.0001
# 223             Benin    2020              Solar  0.0070
# 267             Benin    2020               Wind  0.0000
# 311             Benin    2020  Biomass and waste  0.0000

# %% [markdown]
# # 2) Importation des données de production d'electricité de Burkina-Faso

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_burkina = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_burkina['value'] = pd.to_numeric(data_burkina['value'], errors='coerce')
data_burkina['period'] = pd.to_numeric(data_burkina['period'], errors='coerce')


#Affichage
data_burkina.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=BFA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %% [markdown]
# Visuaalisation pour l'année 2020

# %%
print(data_burkina.productName.unique())

data_2020 = data_burkina[data_burkina['period']== 2020]

print(data_2020)
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']
#     countryRegionName  period        productName  value
# 3        Burkina Faso    2020            Nuclear  0.000
# 47       Burkina Faso    2020               Coal  0.000
# 91       Burkina Faso    2020        Natural gas  0.000
# 135      Burkina Faso    2020                Oil  1.292
# 179      Burkina Faso    2020   Hydroelectricity  0.110
# 223      Burkina Faso    2020              Solar  0.090
# 267      Burkina Faso    2020               Wind  0.000
# 311      Burkina Faso    2020  Biomass and waste  0.096

# %% [markdown]
# # 3) Importation des données de production d'electricité de Cape-Vert

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_cap = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_cap['value'] = pd.to_numeric(data_cap['value'], errors='coerce')
data_cap['period'] = pd.to_numeric(data_cap['period'], errors='coerce')


#Affichage
data_cap.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=CPV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_cap.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 4) Importation des données de production d'electricité de Côte d'Ivoir

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_cote = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_cote['value'] = pd.to_numeric(data_cote['value'], errors='coerce')
data_cote['period'] = pd.to_numeric(data_cote['period'], errors='coerce')


#Affichage
data_cote.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=CIV&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_cote.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 5) Importation des données de production d'electricité de Gambie

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_gambie = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_gambie['value'] = pd.to_numeric(data_gambie['value'], errors='coerce')
data_gambie['period'] = pd.to_numeric(data_gambie['period'], errors='coerce')


#Affichage
data_gambie.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=GMB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_gambie.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 6) Importation des données de production d'electricité de Ghana

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_ghana = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_ghana['value'] = pd.to_numeric(data_ghana['value'], errors='coerce')
data_ghana['period'] = pd.to_numeric(data_ghana['period'], errors='coerce')


#Affichage
data_ghana.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=GHA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_ghana.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 7) Importation des données de production d'electricité de  la Guinée

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_guine = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_guine['value'] = pd.to_numeric(data_guine['value'], errors='coerce')
data_guine['period'] = pd.to_numeric(data_guine['period'], errors='coerce')


#Affichage
data_guine.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=GIN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_guine.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 8) Importation des données de production d'electricité de  la Guinée-Bissau

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_guine_b = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_guine_b['value'] = pd.to_numeric(data_guine_b['value'], errors='coerce')
data_guine_b['period'] = pd.to_numeric(data_guine_b['period'], errors='coerce')


#Affichage
data_guine_b.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=GNB&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_guine_b.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 9) Importation des données de production d'electricité du Liberia

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_liberia = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_liberia['value'] = pd.to_numeric(data_liberia['value'], errors='coerce')
data_liberia['period'] = pd.to_numeric(data_liberia['period'], errors='coerce')


#Affichage
data_liberia.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=LBR&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_liberia.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 10) Importation des données de production d'electricité du Mali

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_mali = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_mali['value'] = pd.to_numeric(data_mali['value'], errors='coerce')
data_mali['period'] = pd.to_numeric(data_mali['period'], errors='coerce')


#Affichage
data_mali.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=MLI&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_mali.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 11) Importation des données de production d'electricité de  la Mauritanie

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_mauritanie = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_mauritanie['value'] = pd.to_numeric(data_mauritanie['value'], errors='coerce')
data_mauritanie['period'] = pd.to_numeric(data_mauritanie['period'], errors='coerce')


#Affichage
data_mauritanie.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=MRT&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_mauritanie.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 12) Importation des données de production d'electricité du Niger

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_niger = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_niger['value'] = pd.to_numeric(data_niger['value'], errors='coerce')
data_niger['period'] = pd.to_numeric(data_niger['period'], errors='coerce')


#Affichage
data_niger.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=NER&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_niger.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar'
#  'Biomass and waste']

# %% [markdown]
# # 13) Importation des données de production d'electricité du Nigeria

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_nigeria = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_nigeria['value'] = pd.to_numeric(data_nigeria['value'], errors='coerce')
data_nigeria['period'] = pd.to_numeric(data_nigeria['period'], errors='coerce')


#Affichage
data_nigeria.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=NGA&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_nigeria.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 14) Importation des données de production d'electricité du Senegal

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "",
    "",
]

# Appel la fonction
data_senegal = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_senegal['value'] = pd.to_numeric(data_senegal['value'], errors='coerce')
data_senegal['period'] = pd.to_numeric(data_senegal['period'], errors='coerce')


#Affichage
data_senegal.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=SEN&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_senegal.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 15) Importation des données de production d'electricité de la Sierra-Leone

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_sierra = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_sierra['value'] = pd.to_numeric(data_sierra['value'], errors='coerce')
data_sierra['period'] = pd.to_numeric(data_sierra['period'], errors='coerce')


#Affichage
data_sierra.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=SLE&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_sierra.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # 16) Importation des données de production d'electricité du Togo

# %%
# Liste des API selon les technologie de production d'electrité
api_list = [
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=31&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=32&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=33&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=116&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=37&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000",
    "https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=38&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000"
]

# Appel la fonction
data_togo = concatenate_eia_data(api_key, api_list)

# conversion du type de valeur en numerique
data_togo['value'] = pd.to_numeric(data_togo['value'], errors='coerce')
data_togo['period'] = pd.to_numeric(data_togo['period'], errors='coerce')


#Affichage
data_togo.head(100)
# Out:
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# Données ajoutées pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=27&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Récupération des données pour l'URL : https://api.eia.gov/v2/international/data/?frequency=annual&data[0]=value&facets[activityId][]=12&facets[productId][]=30&facets[countryRegionId][]=TGO&facets[unit][]=BKWH&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000
# Données importées avec succès.
# ...

# %%
print(data_togo.productName.unique())
# Out:
# ['Nuclear' 'Coal' 'Natural gas' 'Oil' 'Hydroelectricity' 'Solar' 'Wind'
#  'Biomass and waste']

# %% [markdown]
# # Concatenation de tous les datasets de different pays

# %%
# Liste des DataFrames à concaténer
dataframes = [
    data_benin,
    data_burkina,
    data_cap,
    data_cote,
    data_gambie,
    data_ghana,
    data_guine,
    data_guine_b,
    data_liberia,
    data_mali,
    data_mauritanie,
    data_niger,
    data_nigeria,
    data_senegal,
    data_sierra,
    data_togo
]

concat_data = pd.concat(dataframes, axis=0)

concat_data.head(100)
# Out:
#    countryRegionName  period  productName  value
# 0              Benin    2023      Nuclear  0.000
# 1              Benin    2022      Nuclear  0.000
# 2              Benin    2021      Nuclear  0.000
# 3              Benin    2020      Nuclear  0.000
# 4              Benin    2019      Nuclear  0.000
# ..               ...     ...          ...    ...
# 95             Benin    2016  Natural gas  0.007
# 96             Benin    2015  Natural gas  0.111
# 97             Benin    2014  Natural gas  0.104
# 98             Benin    2013  Natural gas  0.038
# 99             Benin    2012  Natural gas  0.000
#
# [100 rows x 4 columns]

# %% [markdown]
# Verification sur la base des Pays

# %%
print(concat_data.countryRegionName.unique())
# Out:
# ['Benin' 'Burkina Faso' 'Cabo Verde' "Cote d'Ivoire" 'Gambia, The' 'Ghana'
#  'Guinea' 'Guinea-Bissau' 'Liberia' 'Mali' 'Mauritania' 'Niger' 'Nigeria'
#  'Senegal' 'Sierra Leone' 'Togo']

# %% [markdown]
# # Sauvegarde du Dataset dans le repertoire des données brutes

# %%
import os
import pandas as pd

# Définir le chemin du fichier
output_dir = "/Users/yibtv/Espace-travail/projet_jhipster/data/raw"  # Chemin absolu sur macOS/Linux
output_file = os.path.join(output_dir, "prod_elect_fromEIA.xlsx")

# Créer le répertoire s'il n'existe pas
os.makedirs(output_dir, exist_ok=True)

# Sauvegarder dans un fichier Excel
try:
    concat_data.to_excel(output_file, index=False)
    print("Données sauvegardées avec succès dans", output_file)
except Exception as e:
    print(f"Erreur lors de la sauvegarde : {e}")
# Out:
# Données sauvegardées avec succès dans /Users/yibtv/Espace-travail/projet_jhipster/data/raw/prod_elect_fromEIA.xlsx
